# %% [markdown]
# <a href="https://colab.research.google.com/github/fonslucens/test_deeplearning/blob/master/single_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
# !python -m pip install -U tensorflow

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
x_data = [[0,0], [1,0], [0,1], [1,1]]
y_data = [[0],[1],[1],[1]]
type(x_data), type(y_data)
# Out:
# (list, list)

# %%
import numpy as np
x_train = np.array(x_data)
y_train = np.array(y_data)
x_train.shape, y_train.shape
# Out:
# ((4, 2), (4, 1))

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(2,)))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer='sgd', loss='mse')
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
model.fit(x_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5202
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5148
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5095
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5044
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4993
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4944
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4895
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4847
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4800
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4754
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4708
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4664
# ...

# %%
model.predict([[0,1]]) # epoch =1
# Out:
# array([[1.5836766]], dtype=float32)

# %%
model.predict([[0,1]])  # epoch =50
# Out:
# array([[0.83018744]], dtype=float32)

# %%
model.predict([[0,1]])  # epoch =500
# Out:
# array([[0.83018744]], dtype=float32)

# %% [markdown]
# y = ax + bx+ c
#
# y = -1.0458019x + 1.3556498x + 0.01205738

# %%
model.get_weights()
# Out:
# [array([[-0.5814972],
#         [ 1.2875829]], dtype=float32), array([0.29609376], dtype=float32)]

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
